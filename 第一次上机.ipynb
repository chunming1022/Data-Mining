# %% [markdown]
# <a href="https://colab.research.google.com/github/chunming1022/Data-Mining/blob/main/21051907_%E9%99%88%E6%B5%A9%E6%98%8E_%E7%AC%AC%E4%B8%80%E6%AC%A1%E4%B8%8A%E6%9C%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **数据可视化**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris

# %matplotlib inline

iris=load_iris()
data=np.array(iris.data)
target=np.array(iris.target)
target=np.expand_dims(target,axis=0)
data_target=np.concatenate((data,target.T),axis=-1)
data_target_meaning=['sepals_length','sepals_width','petals_length','petals_witdh','class']

df=pd.DataFrame({key:value for key,value in zip(data_target_meaning,data_target.T)})

# %%
df
# Out:
#      sepals_length  sepals_width  petals_length  petals_witdh  class
# 0              5.1           3.5            1.4           0.2    0.0
# 1              4.9           3.0            1.4           0.2    0.0
# 2              4.7           3.2            1.3           0.2    0.0
# 3              4.6           3.1            1.5           0.2    0.0
# 4              5.0           3.6            1.4           0.2    0.0
# ..             ...           ...            ...           ...    ...
# 145            6.7           3.0            5.2           2.3    2.0
# 146            6.3           2.5            5.0           1.9    2.0
# 147            6.5           3.0            5.2           2.0    2.0
# 148            6.2           3.4            5.4           2.3    2.0
# 149            5.9           3.0            5.1           1.8    2.0
#
# [150 rows x 5 columns]

# %%
#直方图
for column in data_target_meaning[:-1]:
    df.plot.hist(column=[column])

# %%
#散点图
df.plot.scatter(x=data_target_meaning[0],y=data_target_meaning[1],c=data_target_meaning[-1],colormap='viridis')
# Out:
# <Axes: xlabel='sepals_length', ylabel='sepals_width'>

# %%
#箱型图
df.boxplot(column=data_target_meaning[:-1])
# Out:
# <Axes: >

# %%
#平行坐标
pd.plotting.parallel_coordinates(df,'class')
# Out:
# <Axes: >

# %%
#散点图矩阵
pd.plotting.scatter_matrix(df[data_target_meaning[:-1]],alpha=0.5,figsize=(10,6),diagonal='kde')
# Out:
# array([[<Axes: xlabel='sepals_length', ylabel='sepals_length'>,
#         <Axes: xlabel='sepals_width', ylabel='sepals_length'>,
#         <Axes: xlabel='petals_length', ylabel='sepals_length'>,
#         <Axes: xlabel='petals_witdh', ylabel='sepals_length'>],
#        [<Axes: xlabel='sepals_length', ylabel='sepals_width'>,
#         <Axes: xlabel='sepals_width', ylabel='sepals_width'>,
#         <Axes: xlabel='petals_length', ylabel='sepals_width'>,
#         <Axes: xlabel='petals_witdh', ylabel='sepals_width'>],
#        [<Axes: xlabel='sepals_length', ylabel='petals_length'>,
#         <Axes: xlabel='sepals_width', ylabel='petals_length'>,
#         <Axes: xlabel='petals_length', ylabel='petals_length'>,
#         <Axes: xlabel='petals_witdh', ylabel='petals_length'>],
#        [<Axes: xlabel='sepals_length', ylabel='petals_witdh'>,
#         <Axes: xlabel='sepals_width', ylabel='petals_witdh'>,
#         <Axes: xlabel='petals_length', ylabel='petals_witdh'>,
# ...

# %%
#KDE图
df[data_target_meaning[:-1]].plot.kde()
# Out:
# <Axes: ylabel='Density'>
